# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/wtitze/4E/main/prime_titles.csv')

# %%
df
# Out:
#      S.no.           Name of the show  ...  IMDb rating  Age of viewers
# 0        1                 Pataal Lok  ...          7.5             18+
# 1        2                     Upload  ...          8.1             16+
# 2        3  The Marvelous Mrs. Maisel  ...          8.7             16+
# 3        4     Four More Shots Please  ...          5.3             18+
# 4        5                    Fleabag  ...          8.7             18+
# ..     ...                        ...  ...          ...             ...
# 399    400                        NaN  ...          NaN             NaN
# 400    401                        NaN  ...          NaN             NaN
# 401    402                        NaN  ...          NaN             NaN
# 402    403                        NaN  ...          NaN             NaN
# 403    404                        NaN  ...          NaN             NaN
#
# [404 rows x 8 columns]

# %%
df.dropna(inplace=True)
df
# Out:
#      S.no.                       Name of the show  ...  IMDb rating  Age of viewers
# 0        1                             Pataal Lok  ...          7.5             18+
# 1        2                                 Upload  ...          8.1             16+
# 2        3              The Marvelous Mrs. Maisel  ...          8.7             16+
# 3        4                 Four More Shots Please  ...          5.3             18+
# 4        5                                Fleabag  ...          8.7             18+
# ..     ...                                    ...  ...          ...             ...
# 373    374                  The Danny Thomas Show  ...          7.2             All
# 374    375  Hitoshi Matsumoto Presents Documental  ...          8.0             18+
# 375    376                  Businessmen VS Aliens  ...          4.5             13+
# 379    380                  Scooter: Secret Agent  ...          6.8             All
# ...

# %%
dati = df['Language'].value_counts()
dati
# Out:
# English     155
# Hindi        17
# Japanese      7
# Suomi         1
# Spanish       1
# Deutsch       1
# Name: Language, dtype: int64

# %%
fig = plt.figure()
ax= plt.axes()

ax.bar(dati.index,dati.values)
# Out:
# <BarContainer object of 6 artists>

# %%
fig = plt.figure(figsize=(10,10))
ax= plt.axes()

ax.pie(dati.values,labels=dati.index)
plt.show()

# %%
dfen = df.replace(df[df['Language']!='English']['Language'].tolist(),'non English')
dfen
# Out:
#      S.no.                       Name of the show  ...  IMDb rating  Age of viewers
# 0        1                             Pataal Lok  ...          7.5             18+
# 1        2                                 Upload  ...          8.1             16+
# 2        3              The Marvelous Mrs. Maisel  ...          8.7             16+
# 3        4                 Four More Shots Please  ...          5.3             18+
# 4        5                                Fleabag  ...          8.7             18+
# ..     ...                                    ...  ...          ...             ...
# 373    374                  The Danny Thomas Show  ...          7.2             All
# 374    375  Hitoshi Matsumoto Presents Documental  ...          8.0             18+
# 375    376                  Businessmen VS Aliens  ...          4.5             13+
# 379    380                  Scooter: Secret Agent  ...          6.8             All
# ...

# %%
from datetime import datetime
past = datetime.now().year - 11


dati = dfen[(dfen['Year of release'] > past)].groupby(['Year of release','Language']).count().reset_index('Language')
datien = dati[dati['Language']=='English']['S.no.']
datinonen = dati[dati['Language']=='non English']['S.no.']

fig = plt.figure(figsize=(10,6))
ax = plt.axes()

plt.suptitle('Show')

ax.bar(datien.index-0.2 , datien , width=.4,label='English')
ax.bar(datinonen.index+0.2 , datinonen , width=.4,label='non English')
ax.legend(loc=0)
